# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Dataset

# %%
HouseHoldmasterdetail = pd.read_excel(r"D:New Hire Assessment Programming Problem (1)\HouseHoldmasterdetail.xlsx")
HouseholIndividualDetails = pd.read_excel(r"D:New Hire Assessment Programming Problem (1)\HouseholIndividualDetails.xlsx")
Viewership_data_day1 = pd.read_excel(r"D:New Hire Assessment Programming Problem (1)\Viewership data day1.xlsx")
Viewership_data_day2 = pd.read_excel(r"D:New Hire Assessment Programming Problem (1)\Viewership data day2.xlsx")
Viewership_data_day3 = pd.read_excel(r"D:New Hire Assessment Programming Problem (1)\Viewership data day3.xlsx")

# %% [markdown]
# ### HouseHoldmasterdetail

# %%
HouseHoldmasterdetail
# Out:
#      HH ID        Cities  Blocks
# 0     5070      Auckland       2
# 1     5076      New York      19
# 2     5123      New York      23
# 3     5142        Dallas       4
# 4     5143        Dallas      23
# ..     ...           ...     ...
# 164   9881  San Franisco      13
# 165   9898      Auckland      13
# 166   9950        Dallas      13
# 167   9952       NewPort      13
# 168   9957      New York       2
#
# [169 rows x 3 columns]

# %%
HouseHoldmasterdetail["Cities"].unique()
# Out:
# array(['Auckland', 'New York', 'Dallas', 'San Franisco', 'NewPort'],
#       dtype=object)

# %%
['New York', 'Dallas', 'NewPort']
# Out:
# ['New York', 'Dallas', 'NewPort']

# %%
d1=HouseHoldmasterdetail[(HouseHoldmasterdetail["Cities"]=="New York") | (HouseHoldmasterdetail["Cities"]=="Dallas") | (HouseHoldmasterdetail["Cities"]=="NewPort")]

# %%
d1
# Out:
#      HH ID    Cities  Blocks
# 1     5076  New York      19
# 2     5123  New York      23
# 3     5142    Dallas       4
# 4     5143    Dallas      23
# 6     5158    Dallas      13
# ..     ...       ...     ...
# 160   9835  New York       3
# 161   9844    Dallas      23
# 166   9950    Dallas      13
# 167   9952   NewPort      13
# 168   9957  New York       2
#
# [133 rows x 3 columns]

# %%
d1["Cities"].unique()
# Out:
# array(['New York', 'Dallas', 'NewPort'], dtype=object)

# %%
['New York', 'Dallas', 'NewPort']
# Out:
# ['New York', 'Dallas', 'NewPort']

# %%
d2=HouseHoldmasterdetail[HouseHoldmasterdetail["Cities"].isin(['New York', 'Dallas', 'NewPort'])]

# %%
d2["Cities"].unique()
# Out:
# array(['New York', 'Dallas', 'NewPort'], dtype=object)

# %%
HouseHoldmasterdetail
# Out:
#      HH ID        Cities  Blocks
# 0     5070      Auckland       2
# 1     5076      New York      19
# 2     5123      New York      23
# 3     5142        Dallas       4
# 4     5143        Dallas      23
# ..     ...           ...     ...
# 164   9881  San Franisco      13
# 165   9898      Auckland      13
# 166   9950        Dallas      13
# 167   9952       NewPort      13
# 168   9957      New York       2
#
# [169 rows x 3 columns]

# %%
d2
# Out:
#      HH ID    Cities  Blocks
# 1     5076  New York      19
# 2     5123  New York      23
# 3     5142    Dallas       4
# 4     5143    Dallas      23
# 6     5158    Dallas      13
# ..     ...       ...     ...
# 160   9835  New York       3
# 161   9844    Dallas      23
# 166   9950    Dallas      13
# 167   9952   NewPort      13
# 168   9957  New York       2
#
# [133 rows x 3 columns]

# %%
HouseHoldmasterdetail.drop(d2.index)
# Out:
#      HH ID        Cities  Blocks
# 0     5070      Auckland       2
# 5     5153      Auckland      13
# 7     5192  San Franisco      23
# 8     5198      Auckland      13
# 10    5232      Auckland      20
# 13    5436      Auckland      23
# 14    5458      Auckland      20
# 18    5532      Auckland      13
# 19    5546      Auckland      12
# 32    5927  San Franisco      19
# 47    6377  San Franisco       2
# 49    6447  San Franisco      12
# 53    6520      Auckland      12
# 57    6688  San Franisco      18
# 63    6850      Auckland      21
# 67    6961  San Franisco       8
# 70    7004      Auckland      23
# 79    7334      Auckland      21
# 86    7467  San Franisco      12
# 92    7811  San Franisco      15
# 97    7879      Auckland      18
# 104   8050      Auckland       3
# 106   8117  San Franisco       5
# 108   8200      Auckland      12
# 110   8247  San Franisco       9
# 111   8279  San Franisco       9
# 128   9027  San Franisco      20
# 135   9188  San Franisco       9
# 136   9230      Auckland      20
# 138   9302  San Franisco      13
# 139   9314  San Franisco       2
# 142   9396      Auckland       5
# 162   9857      Auckland       2
# 163   9859  San Franisco      12
# 164   9881  San Franisco      13
# 165   9898      Auckland      13

# %%
HouseHoldmasterdetail.shape
# Out:
# (169, 3)

# %%
HouseHoldmasterdetail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HH ID   169 non-null    int64
#  1   Cities  169 non-null    object
#  2   Blocks  169 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 4.1+ KB

# %%
HouseHoldmasterdetail.nunique()
# Out:
# HH ID     169
# Cities      5
# Blocks     15
# dtype: int64

# %%
HouseHoldmasterdetail
# Out:
#      HH ID        Cities  Blocks
# 0     5070      Auckland       2
# 1     5076      New York      19
# 2     5123      New York      23
# 3     5142        Dallas       4
# 4     5143        Dallas      23
# ..     ...           ...     ...
# 164   9881  San Franisco      13
# 165   9898      Auckland      13
# 166   9950        Dallas      13
# 167   9952       NewPort      13
# 168   9957      New York       2
#
# [169 rows x 3 columns]

# %%
a=HouseHoldmasterdetail["Cities"].value_counts()
a
# Out:
# New York        68
# Dallas          48
# Auckland        19
# San Franisco    17
# NewPort         17
# Name: Cities, dtype: int64

# %%
print(a)
# Out:
# New York        68
# Dallas          48
# Auckland        19
# San Franisco    17
# NewPort         17
# Name: Cities, dtype: int64

# %%
# Plot a bar chart of the value counts
plt.bar(a.index, a.values)

# Add labels and title to the chart
plt.xlabel('Cities')
plt.ylabel('Count')
plt.title('Value Counts for Cities')

# Show the chart
plt.show()

# %%
b=HouseHoldmasterdetail["Blocks"].value_counts()
b
# Out:
# 13    32
# 2     24
# 4     21
# 12    21
# 23    14
# 9     13
# 20    11
# 3      8
# 19     6
# 18     6
# 5      6
# 21     3
# 8      2
# 16     1
# 15     1
# Name: Blocks, dtype: int64

# %%
# Plot a bar chart of the value counts
plt.bar(b.index, b.values)

# Add labels and title to the chart
plt.xlabel('Blocks')
plt.ylabel('Count')
plt.title('Value Counts for Blocks')

# Show the chart
plt.show()

# %%
HouseHoldmasterdetail.isnull().sum()
#No missing value
# Out:
# HH ID     0
# Cities    0
# Blocks    0
# dtype: int64

# %%
HouseHoldmasterdetail.nunique()
# Out:
# HH ID     169
# Cities      5
# Blocks     15
# dtype: int64

# %% [markdown]
# ### HouseholIndividualDetails

# %%
HouseholIndividualDetails
# Out:
#        HH  INDIVIDUAL_ID       WEIGHT  Age_in_years Sex Education
# 0    6283              4  4844.772198            50   M       SSC
# 1    6283              1  6637.126847            42   F       SSC
# 2    6283              5  9989.732835            17   M       SSC
# 3    6658              2  9875.840557            58   M  Graduate
# 4    6658              3  9432.010587            49   F       SSC
# ..    ...            ...          ...           ...  ..       ...
# 520  5143              3  9608.890364            53   F       HSC
# 521  5143              4  7195.189063            36   M       HSC
# 522  5143              5  9218.902004            32   M        PG
# 523  5153              2  7346.853146            52   F       SSC
# 524  5153              3  8639.334048             4   M       HSC
#
# [525 rows x 6 columns]

# %%
HouseholIndividualDetails.describe()
# Out:
#                 HH  INDIVIDUAL_ID       WEIGHT  Age_in_years
# count   525.000000     525.000000   525.000000    525.000000
# mean   7478.087619       3.005714  5035.849263     39.091429
# std    1481.409890       1.414877  2985.155222     17.905478
# min    5070.000000       1.000000     6.907993      3.000000
# 25%    6169.000000       2.000000  2334.532515     24.000000
# 50%    7375.000000       3.000000  5041.881930     41.000000
# 75%    8806.000000       4.000000  7623.115878     52.000000
# max    9957.000000       5.000000  9989.732835     90.000000

# %%
HouseholIndividualDetails.nunique()
# Out:
# HH               169
# INDIVIDUAL_ID      5
# WEIGHT           525
# Age_in_years      77
# Sex                2
# Education          4
# dtype: int64

# %%
HouseholIndividualDetails.isnull().sum()
# Out:
# HH               0
# INDIVIDUAL_ID    0
# WEIGHT           0
# Age_in_years     0
# Sex              0
# Education        0
# dtype: int64

# %%
bb=HouseholIndividualDetails["Sex"].value_counts()
bb
# Out:
# M    282
# F    243
# Name: Sex, dtype: int64

# %%
# Create a pie chart of the value counts
plt.pie(bb.values, labels=bb.index, autopct='%1.2f%%')

# Add title to the chart
plt.title('Sex')

# Show the chart
plt.show()

# %%
HouseholIndividualDetails["Education"]
# Out:
# 0           SSC
# 1           SSC
# 2           SSC
# 3      Graduate
# 4           SSC
#          ...
# 520         HSC
# 521         HSC
# 522          PG
# 523         SSC
# 524         HSC
# Name: Education, Length: 525, dtype: object

# %%
c=HouseholIndividualDetails["Education"].value_counts()
c
# Out:
# SSC         243
# HSC         237
# Graduate     24
# PG           21
# Name: Education, dtype: int64

# %%
# Create a pie chart of the value counts
plt.pie(c.values, labels=c.index, autopct='%1.1f%%')

# Add title to the chart
plt.title('Education')

# Show the chart
plt.show()

# %%
# Create a histogram of age
plt.hist(HouseholIndividualDetails['Age_in_years'], bins=10)

# Add labels and title to the chart
plt.xlabel('Age_in_years')
plt.ylabel('Count')
plt.title('Age Distribution')

# Show the chart
plt.show()

# %% [markdown]
# ### Viewership data

# %%
Viewership_data_day1
# Out:
#           Date    HH  INDIVIDUAL_ID  Duration in minutes Channels
# 0   2022-12-01  6283              4                   66      CH3
# 1   2022-12-01  6283              1                   61      CH5
# 2   2022-12-01  6283              4                    1      CH1
# 3   2022-12-01  6283              5                   97      Ch2
# 4   2022-12-01  6658              2                   38      Ch2
# ..         ...   ...            ...                  ...      ...
# 796 2022-12-01  5153              2                   84      CH5
# 797 2022-12-01  5153              2                   35      CH5
# 798 2022-12-01  5153              2                   95      CH5
# 799 2022-12-01  5153              2                   27      Ch2
# 800 2022-12-01  5153              3                   86      CH4
#
# [801 rows x 5 columns]

# %%
Viewership_data_day1.describe()
# Out:
#                 HH  INDIVIDUAL_ID  Duration in minutes
# count   801.000000     801.000000           801.000000
# mean   7545.253433       3.009988            50.991261
# std    1492.663860       1.399071            28.745455
# min    5070.000000       1.000000             1.000000
# 25%    6216.000000       2.000000            26.000000
# 50%    7463.000000       3.000000            52.000000
# 75%    8936.000000       4.000000            76.000000
# max    9957.000000       5.000000           100.000000

# %%
Viewership_data_day1.nunique()
# Out:
# Date                     1
# HH                     169
# INDIVIDUAL_ID            5
# Duration in minutes    100
# Channels                 5
# dtype: int64

# %%
Viewership_data_day1.isnull().sum()
# Out:
# Date                   0
# HH                     0
# INDIVIDUAL_ID          0
# Duration in minutes    0
# Channels               0
# dtype: int64

# %%
Viewership_data_day2
# Out:
#           Date    HH  INDIVIDUAL_ID  Duration in minutes Channels
# 0   2022-12-02  6283              4                    7      CH4
# 1   2022-12-02  6283              1                   97      CH1
# 2   2022-12-02  6283              4                   99      CH1
# 3   2022-12-02  6283              5                   69      Ch2
# 4   2022-12-02  6658              2                   18      CH1
# ..         ...   ...            ...                  ...      ...
# 796 2022-12-02  5153              2                   86      CH4
# 797 2022-12-02  5153              2                   75      CH1
# 798 2022-12-02  5153              2                   53      CH5
# 799 2022-12-02  5153              2                   87      Ch2
# 800 2022-12-02  5153              3                   40      CH4
#
# [801 rows x 5 columns]

# %%
Viewership_data_day2.describe()
# Out:
#                 HH  INDIVIDUAL_ID  Duration in minutes
# count   801.000000     801.000000           801.000000
# mean   7545.253433       3.009988            51.141074
# std    1492.663860       1.399071            29.120505
# min    5070.000000       1.000000             1.000000
# 25%    6216.000000       2.000000            26.000000
# 50%    7463.000000       3.000000            49.000000
# 75%    8936.000000       4.000000            77.000000
# max    9957.000000       5.000000           100.000000

# %%
Viewership_data_day2.nunique()
# Out:
# Date                     1
# HH                     169
# INDIVIDUAL_ID            5
# Duration in minutes    100
# Channels                 5
# dtype: int64

# %%
Viewership_data_day2.isnull().sum()
# Out:
# Date                   0
# HH                     0
# INDIVIDUAL_ID          0
# Duration in minutes    0
# Channels               0
# dtype: int64

# %%
Viewership_data_day3
# Out:
#           Date    HH  INDIVIDUAL_ID  Duration in minutes Channels
# 0   2022-12-03  6283              4                   54      CH5
# 1   2022-12-03  6283              1                   95      CH1
# 2   2022-12-03  6283              4                   21      CH3
# 3   2022-12-03  6283              5                   67      Ch2
# 4   2022-12-03  6658              2                   48      CH4
# ..         ...   ...            ...                  ...      ...
# 796 2022-12-03  5153              2                   71      CH5
# 797 2022-12-03  5153              2                   54      CH5
# 798 2022-12-03  5153              2                   34      CH3
# 799 2022-12-03  5153              2                   53      Ch2
# 800 2022-12-03  5153              3                   25      CH3
#
# [801 rows x 5 columns]

# %%
Viewership_data_day3.describe()
# Out:
#                 HH  INDIVIDUAL_ID  Duration in minutes
# count   801.000000     801.000000           801.000000
# mean   7545.253433       3.009988            50.609238
# std    1492.663860       1.399071            29.372919
# min    5070.000000       1.000000             1.000000
# 25%    6216.000000       2.000000            24.000000
# 50%    7463.000000       3.000000            51.000000
# 75%    8936.000000       4.000000            78.000000
# max    9957.000000       5.000000           100.000000

# %%
Viewership_data_day3.nunique()
# Out:
# Date                     1
# HH                     169
# INDIVIDUAL_ID            5
# Duration in minutes    100
# Channels                 5
# dtype: int64

# %%
Viewership_data_day3.isnull().sum()
# Out:
# Date                   0
# HH                     0
# INDIVIDUAL_ID          0
# Duration in minutes    0
# Channels               0
# dtype: int64

# %% [markdown]
# ### Combining Data

# %%
# HouseholIndividualDetails and HouseHoldmasterdetail combine and make full information of # Househol

data= pd.merge(HouseholIndividualDetails,HouseHoldmasterdetail,left_on="HH",right_on="HH ID")

# %%
data
# Out:
#        HH  INDIVIDUAL_ID       WEIGHT  Age_in_years Sex Education  HH ID  \
# 0    6283              4  4844.772198            50   M       SSC   6283
# 1    6283              1  6637.126847            42   F       SSC   6283
# 2    6283              5  9989.732835            17   M       SSC   6283
# 3    6658              2  9875.840557            58   M  Graduate   6658
# 4    6658              3  9432.010587            49   F       SSC   6658
# ..    ...            ...          ...           ...  ..       ...    ...
# 520  5143              3  9608.890364            53   F       HSC   5143
# 521  5143              4  7195.189063            36   M       HSC   5143
# 522  5143              5  9218.902004            32   M        PG   5143
# 523  5153              2  7346.853146            52   F       SSC   5153
# 524  5153              3  8639.334048             4   M       HSC   5153
#
#        Cities  Blocks
# 0      Dallas       4
# 1      Dallas       4
# 2      Dallas       4
# 3      Dallas       4
# 4      Dallas       4
# ..        ...     ...
# 520    Dallas      23
# 521    Dallas      23
# 522    Dallas      23
# 523  Auckland      13
# 524  Auckland      13
#
# [525 rows x 9 columns]

# %%
# dataframe informations
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 525 entries, 0 to 524
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HH             525 non-null    int64
#  1   INDIVIDUAL_ID  525 non-null    int64
#  2   WEIGHT         525 non-null    float64
#  3   Age_in_years   525 non-null    int64
#  4   Sex            525 non-null    object
#  5   Education      525 non-null    object
#  6   HH ID          525 non-null    int64
#  7   Cities         525 non-null    object
#  8   Blocks         525 non-null    int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 41.0+ KB

# %%
data.describe()
# Out:
# Sex             F           M
# count    4.000000    4.000000
# mean    60.750000   70.500000
# std     61.418645   66.700825
# min      7.000000   14.000000
# 25%      9.250000   14.000000
# 50%     54.500000   62.000000
# 75%    106.000000  118.500000
# max    127.000000  144.000000

# %%
data.nunique()
# Out:
# HH               169
# INDIVIDUAL_ID      5
# WEIGHT           525
# Age_in_years      77
# Sex                2
# Education          4
# HH ID            169
# Cities             5
# Blocks            15
# dtype: int64

# %%
data.isnull().sum()
# Out:
# HH               0
# INDIVIDUAL_ID    0
# WEIGHT           0
# Age_in_years     0
# Sex              0
# Education        0
# HH ID            0
# Cities           0
# Blocks           0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Channel performance matrix:

# %%
Viewership_data_day2
# Out:
#           Date    HH  INDIVIDUAL_ID  Duration in minutes Channels
# 0   2022-12-02  6283              4                    7      CH4
# 1   2022-12-02  6283              1                   97      CH1
# 2   2022-12-02  6283              4                   99      CH1
# 3   2022-12-02  6283              5                   69      Ch2
# 4   2022-12-02  6658              2                   18      CH1
# ..         ...   ...            ...                  ...      ...
# 796 2022-12-02  5153              2                   86      CH4
# 797 2022-12-02  5153              2                   75      CH1
# 798 2022-12-02  5153              2                   53      CH5
# 799 2022-12-02  5153              2                   87      Ch2
# 800 2022-12-02  5153              3                   40      CH4
#
# [801 rows x 5 columns]

# %%
Viewership_data_day2 = Viewership_data_day2.rename(columns={'Duration_in_minutes': 'Duration in minutes'})

# %%
day=pd.concat([Viewership_data_day1,Viewership_data_day2,Viewership_data_day3],axis=0)
day
# Out:
#           Date    HH  INDIVIDUAL_ID  Duration in minutes Channels
# 0   2022-12-01  6283              4                   66      CH3
# 1   2022-12-01  6283              1                   61      CH5
# 2   2022-12-01  6283              4                    1      CH1
# 3   2022-12-01  6283              5                   97      Ch2
# 4   2022-12-01  6658              2                   38      Ch2
# ..         ...   ...            ...                  ...      ...
# 796 2022-12-03  5153              2                   71      CH5
# 797 2022-12-03  5153              2                   54      CH5
# 798 2022-12-03  5153              2                   34      CH3
# 799 2022-12-03  5153              2                   53      Ch2
# 800 2022-12-03  5153              3                   25      CH3
#
# [2403 rows x 5 columns]

# %%
d1=day.groupby(['Channels'])['Duration in minutes'].mean().reset_index()
d1
# Out:
#   Channels  Duration in minutes
# 0      CH1            48.673387
# 1      CH3            50.556468
# 2      CH4            51.162281
# 3      CH5            51.184411
# 4      Ch2            53.264840

# %%
# Create a bar chart
fig, ax = plt.subplots(figsize=(8,6))
ax.bar(d1['Channels'], d1['Duration in minutes'], color='b')

# Add labels and titles
ax.set_xlabel('Channels')
ax.set_ylabel('Average duration in minutes')
ax.set_title('Average duration by channel')

plt.show()
